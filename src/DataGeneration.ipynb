# %%
import pandas as pd
import numpy as np

# %%
# rated_fad_cfm
# rated_motor_output_kw
# rated_pressure_bar
# flow_tolerance_pct
# motor_power_tolerance_pct
# temp_upper_limit_c

# %%
df=pd.read_excel(r"C:\Users\Admin\OneDrive - C4i4 Lab, Samarth Udyog Technology Forum,\Attachments\Office work\DigitalTwin2\data\KES22_8p5_synthetic_test_data.xlsx")

# %% [markdown]
# ### Rated FAD CFM

# %%
df['rated_fad_cfm'] = 127

# %%
df.columns
# Out:
# Index(['timestamp', 'elapsed_time_min', 'elapsed_time_sec', 'phase',
#        'airend_discharge_temp_c', 'delivery_pressure_kg_cm2g',
#        'oil_cooler_inlet_temp_c', 'oil_cooler_outlet_temp_c',
#        'aftercooler_inlet_temp_c', 'aftercooler_outlet_temp_c', 'fad_cfm',
#        'motor_output_power_kw', 'package_input_power_kw', 'input_voltage_v',
#        'current_package_input_a', 'aos_tank_inlet_pressure_kg_cm2g',
#        'air_inlet_temp_c', 'power_factor', 'tolerance_flow_pct',
#        'spc_kw_per_m3_min', 'tolerance_spc_pct', 'rated_fad_cfm'],
#       dtype='str')

# %%
df["rated_fad_cfm"]
# Out:
# 0      127
# 1      127
# 2      127
# 3      127
# 4      127
#       ...
# 716    127
# 717    127
# 718    127
# 719    127
# 720    127
# Name: rated_fad_cfm, Length: 721, dtype: int64

# %%
df["flow_tolerance_pct(%)"]=7

# %%
df["rated_motor_output_kw"]=22
df["(motor_power_tolerance_pct(%))"]=5

# %%
print(df.columns)
# Out:
# Index(['timestamp', 'elapsed_time_min', 'elapsed_time_sec', 'phase',
#        'airend_discharge_temp_c', 'delivery_pressure_kg_cm2g',
#        'oil_cooler_inlet_temp_c', 'oil_cooler_outlet_temp_c',
#        'aftercooler_inlet_temp_c', 'aftercooler_outlet_temp_c', 'fad_cfm',
#        'motor_output_power_kw', 'package_input_power_kw', 'input_voltage_v',
#        'current_package_input_a', 'aos_tank_inlet_pressure_kg_cm2g',
#        'air_inlet_temp_c', 'power_factor', 'tolerance_flow_pct',
#        'spc_kw_per_m3_min', 'tolerance_spc_pct', 'rated_fad_cfm',
#        'flow_tolerance_pct(%)', 'rated_motor_output_kw',
#        '(motor_power_tolerance_pct(%))'],
#       dtype='str')

# %%
df.head()
# Out:
#             timestamp  elapsed_time_min  elapsed_time_sec          phase  \
# 0 2026-02-14 16:23:00              0.00                 0  Phase1_Warmup
# 1 2026-02-14 16:23:15              0.25                15  Phase1_Warmup
# 2 2026-02-14 16:23:30              0.50                30  Phase1_Warmup
# 3 2026-02-14 16:23:45              0.75                45  Phase1_Warmup
# 4 2026-02-14 16:24:00              1.00                60  Phase1_Warmup
#
#    airend_discharge_temp_c  delivery_pressure_kg_cm2g oil_cooler_inlet_temp_c  \
# 0                   34.279                     0.0434                  35.478
# 1                   34.570                     1.1577                  35.638
# 2                   34.628                     2.1511                  35.921
# 3                   34.851                     3.0187                  36.209
# 4                   34.986                     3.7299                  36.307
#
#    oil_cooler_outlet_temp_c  aftercooler_inlet_temp_c  \
# ...
